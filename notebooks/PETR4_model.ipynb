# %% [markdown]
# # Projeto Integrado Final - Deep Learning
#
# Desenvolvimento de modelo classificação utilizando Redes Neurais Convolucionais (CNN) ou Redes Neurais Recorrentes (RNN), com base na tendencia de mercado dos ultimos 15 dias, considerando o "close" da ação em base de dados suavizada.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, LSTM, Dropout, MaxPooling1D, Flatten
from tensorflow.keras.utils import to_categorical, plot_model
from keras.callbacks import ModelCheckpoint
from collections import defaultdict

# %%
df_train = pd.read_csv('../data/PETR4.SA/treino.csv')
df_test = pd.read_csv('../data/PETR4.SA/teste.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_train.head(2)
# Out:
#    Unnamed: 0        Date     Close  Smoothed_Close  Label  Past_1_Days_Close  \
# 0           1  2000-01-24  1.274788        1.347845     -1           1.283923
# 1           2  2000-01-25  1.274788        1.340540     -1           1.274788
#
#    Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  Past_5_Days_Close  \
# 0           1.311824           1.314787           1.324169           1.317996
# 1           1.283923           1.311824           1.314787           1.324169
#
#    Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# 0           1.333305           1.314787           1.353798           1.351823
# 1           1.317996           1.333305           1.314787           1.353798
#
#    Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# 0            1.385896            1.357995            1.351823
# 1            1.351823            1.385896            1.357995
#
#    Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# 0            1.356514            1.370341            1.450586
# 1            1.351823            1.356514            1.370341

# %%
df_test.head(2)
# Out:
#    Unnamed: 0        Date     Close  Smoothed_Close  Label  Past_1_Days_Close  \
# 0        4809  2019-02-26  9.467936        9.376527      1           9.510681
# 1        4810  2019-02-27  9.646040        9.403478      1           9.467936
#
#    Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  Past_5_Days_Close  \
# 0           9.663848           9.760024           9.631790           9.752899
# 1           9.510681           9.663848           9.760024           9.631790
#
#    Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# 0           9.532050           9.560549           9.599731           9.279146
# 1           9.752899           9.532050           9.560549           9.599731
#
#    Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# 0            9.161598            8.848140            8.951439
# 1            9.279146            9.161598            8.848140
#
#    Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# 0            8.937191            9.079673            9.289832
# 1            8.951439            8.937191            9.079673

# %%
nome_arquivo = 'PETR4'
# EDA
print(f"EDA para {nome_arquivo}:")
print(f"Descrição dos dados:\n{df_train.describe()}\n")
print(f"Contagem de valores NaN por coluna:\n{df_train.isna().sum()}\n")
print(f"Contagem dos rótulos:\n{df_train['Label'].value_counts()}\n")
# Out:
# EDA para PETR4:
# Descrição dos dados:
#         Unnamed: 0        Close  Smoothed_Close        Label  \
# count  4808.000000  4808.000000     4808.000000  4808.000000
# mean   2404.500000     5.126396        5.111402    -0.103993
# std    1388.094377     2.810534        2.790427     0.994681
# min       1.000000     1.080224        1.200894    -1.000000
# 25%    1202.750000     2.523248        2.533339    -1.000000
# 50%    2404.500000     5.331852        5.349307    -1.000000
# 75%    3606.250000     6.990364        6.965855     1.000000
# max    4808.000000    14.551721       13.432679     1.000000
#
#        Past_1_Days_Close  Past_2_Days_Close  Past_3_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean            5.124685           5.122948           5.121191
# std             2.810369           2.810144           2.809884
# min             1.080224           1.080224           1.080224
# 25%             2.519004           2.518208           2.516232
# 50%             5.331822           5.330961           5.330100
# 75%             6.990364           6.990364           6.984855
# max            14.551721          14.551721          14.551721
#
#        Past_4_Days_Close  Past_5_Days_Close  Past_6_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean            5.119464           5.117709           5.116004
# std             2.809664           2.809404           2.809212
# min             1.080224           1.080224           1.080224
# 25%             2.513835           2.508511           2.506351
# 50%             5.330100           5.329587           5.327880
# 75%             6.982575           6.981311           6.979728
# max            14.551721          14.551721          14.551721
#
#        Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean            5.114289           5.112574           5.110925
# std             2.809015           2.808793           2.808673
# min             1.080224           1.080224           1.080224
# 25%             2.506119           2.506119           2.505502
# 50%             5.325965           5.325195           5.323849
# 75%             6.977312           6.972238           6.969759
# max            14.551721          14.551721          14.551721
#
#        Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# count         4808.000000         4808.000000         4808.000000
# mean             5.109308            5.107750            5.106169
# std              2.808579            2.808582            2.808557
# min              1.080224            1.080224            1.080224
# 25%              2.502724            2.499175            2.496860
# 50%              5.322553            5.322385            5.321037
# 75%              6.968959            6.967902            6.966150
# max             14.551721           14.551721           14.551721
#
#        Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# count         4808.000000         4808.000000         4808.000000
# mean             5.104593            5.102989            5.101359
# std              2.808534            2.808465            2.808309
# min              1.080224            1.080224            1.080224
# 25%              2.496860            2.496860            2.496860
# 50%              5.319856            5.319856            5.319856
# 75%              6.963105            6.961744            6.959695
# max             14.551721           14.551721           14.551721
#
# Contagem de valores NaN por coluna:
# Unnamed: 0            0
# Date                  0
# Close                 0
# Smoothed_Close        0
# Label                 0
# Past_1_Days_Close     0
# Past_2_Days_Close     0
# Past_3_Days_Close     0
# Past_4_Days_Close     0
# Past_5_Days_Close     0
# Past_6_Days_Close     0
# Past_7_Days_Close     0
# Past_8_Days_Close     0
# Past_9_Days_Close     0
# Past_10_Days_Close    0
# Past_11_Days_Close    0
# Past_12_Days_Close    0
# Past_13_Days_Close    0
# Past_14_Days_Close    0
# Past_15_Days_Close    0
# dtype: int64
#
# Contagem dos rótulos:
# Label
# -1    2654
#  1    2154
# Name: count, dtype: int64

# %%
# COMPARAÇÃO ENTRE PREÇOS DE FECHAMENTO E PREÇOS DE FECHAMENTO SUAVIZADOS
plt.figure(figsize=(14, 7))
plt.plot(df_train['Close'], label='Close')
plt.plot(df_train['Smoothed_Close'], label='Smoothed Close')
plt.title(f'Preços de Fechamento e Suavizados - {nome_arquivo}')
plt.legend()
plt.show()

# %%
# DISTRIBUIÇÃO DOS RÓTULOS
sns.countplot(x='Label', data=df_train)
plt.title(f'Distribuição de Classes - {nome_arquivo}')
plt.show()

# %% [markdown]
# ## Treinamento de modelo de Redes Neurais Recorrentes (RNN)

# %%
## NORMALIZAÇÃO DOS DADOS

# Normalizador para as features
scaler = StandardScaler()

# Função para converter rótulos em formato categórico
def converter_para_categorico(y):
    if y.min() == -1:  # Se os rótulos forem -1 e 1
        y = (y + 1) // 2  # Converter rótulos para 0 e 1
    return to_categorical(y)

X_train = df_train.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_train = df_train['Label']

X_test = df_test.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_test = df_test['Label']

# Normalizar as features
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Converter os rótulos para formato categórico
y_train_cat = converter_para_categorico(y_train)
y_test_cat = converter_para_categorico(y_test)

# %%
# Cria e treina a rede LSTM
historicos = {}

model_rnn = Sequential([     
        LSTM(150, return_sequences=True, input_shape=(X_train.shape[1], 1)),
        Dropout(0.2),
        LSTM(50, return_sequences=False, activation='relu'),
        Dense(y_train_cat.shape[1], activation='sigmoid')
    ])

# Compilando o modelo com entropia cruzada categórica para classificação binária
# A acurácia é usada como métrica para avaliação
model_rnn.compile(loss='binary_crossentropy', metrics=['accuracy'])

# Treinando o modelo com os dados
# Epochs define o número de vezes que o modelo verá todo o conjunto de dados
# Batch size é o número de amostras que o modelo vê antes de atualizar os pesos
# Verbose=1 mostra a barra de progresso do treinamento

checkpointer = ModelCheckpoint(filepath='../models/melhor_rnn_PETR4.keras', verbose=1,  save_best_only=True, monitor='val_accuracy')

historico_rnn = model_rnn.fit(X_train, y_train_cat, epochs=100, batch_size=64, validation_split=0.2, verbose=1, callbacks=[checkpointer],shuffle=True)
# Out:
# Epoch 1/100
# /Users/cintia.duarte/Documents/develop/NEURAL-NETWORKS-REGRESSION/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5577 - loss: 0.6890
# Epoch 1: val_accuracy improved from -inf to 0.52287, saving model to ../models/melhor_rnn_PETR4.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5577 - loss: 0.6890 - val_accuracy: 0.5229 - val_loss: 0.6889
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5635 - loss: 0.6848
# Epoch 2: val_accuracy improved from 0.52287 to 0.53222, saving model to ../models/melhor_rnn_PETR4.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5635 - loss: 0.6848 - val_accuracy: 0.5322 - val_loss: 0.6834
# Epoch 3/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5469 - loss: 0.6856
# Epoch 3: val_accuracy did not improve from 0.53222
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5473 - loss: 0.6855 - val_accuracy: 0.5281 - val_loss: 0.6826
# Epoch 4/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5525 - loss: 0.6796
# Epoch 4: val_accuracy improved from 0.53222 to 0.54262, saving model to ../models/melhor_rnn_PETR4.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5533 - loss: 0.6794 - val_accuracy: 0.5426 - val_loss: 0.6698
# Epoch 5/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5828 - loss: 0.6684
# Epoch 5: val_accuracy improved from 0.54262 to 0.69439, saving model to ../models/melhor_rnn_PETR4.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5827 - loss: 0.6683 - val_accuracy: 0.6944 - val_loss: 0.6513
# Epoch 6/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6093 - loss: 0.6538
# Epoch 6: val_accuracy did not improve from 0.69439
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6093 - loss: 0.6537 - val_accuracy: 0.5977 - val_loss: 0.6608
# Epoch 7/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6300 - loss: 0.6474
# Epoch 7: val_accuracy did not improve from 0.69439
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6306 - loss: 0.6465 - val_accuracy: 0.6237 - val_loss: 0.6159
# Epoch 8/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6465 - loss: 0.6208
# Epoch 8: val_accuracy improved from 0.69439 to 0.73701, saving model to ../models/melhor_rnn_PETR4.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6469 - loss: 0.6204 - val_accuracy: 0.7370 - val_loss: 0.6589
# Epoch 9/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6738 - loss: 0.6055
# Epoch 9: val_accuracy did not improve from 0.73701
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6740 - loss: 0.6048 - val_accuracy: 0.6881 - val_loss: 0.5612
# Epoch 10/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6747 - loss: 0.5918
# Epoch 10: val_accuracy improved from 0.73701 to 0.80353, saving model to ../models/melhor_rnn_PETR4.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6751 - loss: 0.5914 - val_accuracy: 0.8035 - val_loss: 0.5062
# Epoch 11/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6935 - loss: 0.5533
# Epoch 11: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6935 - loss: 0.5536 - val_accuracy: 0.6871 - val_loss: 0.5668
# Epoch 12/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6931 - loss: 0.5772
# Epoch 12: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.6929 - loss: 0.5769 - val_accuracy: 0.6279 - val_loss: 0.7234
# Epoch 13/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6849 - loss: 0.5678
# Epoch 13: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6851 - loss: 0.5677 - val_accuracy: 0.6331 - val_loss: 0.9077
# Epoch 14/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7003 - loss: 0.5498
# Epoch 14: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7004 - loss: 0.5498 - val_accuracy: 0.6933 - val_loss: 0.5291
# Epoch 15/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7040 - loss: 0.5542
# Epoch 15: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7040 - loss: 0.5542 - val_accuracy: 0.7162 - val_loss: 0.5580
# Epoch 16/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7206 - loss: 0.5477
# Epoch 16: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7203 - loss: 0.5479 - val_accuracy: 0.6154 - val_loss: 0.7120
# Epoch 17/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6979 - loss: 0.5548
# Epoch 17: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6981 - loss: 0.5545 - val_accuracy: 0.7173 - val_loss: 0.5401
# Epoch 18/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7146 - loss: 0.5435
# Epoch 18: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7145 - loss: 0.5434 - val_accuracy: 0.6674 - val_loss: 0.7192
# Epoch 19/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6990 - loss: 0.5637
# Epoch 19: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6993 - loss: 0.5630 - val_accuracy: 0.6881 - val_loss: 0.6252
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7030 - loss: 0.5372
# Epoch 20: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7032 - loss: 0.5372 - val_accuracy: 0.6227 - val_loss: 0.9289
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7244 - loss: 0.5482
# Epoch 21: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7243 - loss: 0.5481 - val_accuracy: 0.6954 - val_loss: 0.5799
# Epoch 22/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7063 - loss: 0.5542
# Epoch 22: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7065 - loss: 0.5537 - val_accuracy: 0.7640 - val_loss: 0.4679
# Epoch 23/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7127 - loss: 0.5384
# Epoch 23: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7124 - loss: 0.5385 - val_accuracy: 0.7568 - val_loss: 0.5355
# Epoch 24/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6989 - loss: 0.5440
# Epoch 24: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6993 - loss: 0.5437 - val_accuracy: 0.7245 - val_loss: 0.5130
# Epoch 25/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6996 - loss: 0.5377
# Epoch 25: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7001 - loss: 0.5373 - val_accuracy: 0.7422 - val_loss: 0.5296
# Epoch 26/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7121 - loss: 0.5441
# Epoch 26: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7123 - loss: 0.5434 - val_accuracy: 0.7256 - val_loss: 0.4717
# Epoch 27/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7064 - loss: 0.5371
# Epoch 27: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7070 - loss: 0.5367 - val_accuracy: 0.6767 - val_loss: 0.6669
# Epoch 28/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7195 - loss: 0.5209
# Epoch 28: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7194 - loss: 0.5207 - val_accuracy: 0.6923 - val_loss: 0.6490
# Epoch 29/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7172 - loss: 0.5402
# Epoch 29: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7172 - loss: 0.5395 - val_accuracy: 0.6705 - val_loss: 0.5964
# Epoch 30/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7301 - loss: 0.5168
# Epoch 30: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7300 - loss: 0.5167 - val_accuracy: 0.7536 - val_loss: 0.4800
# Epoch 31/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7174 - loss: 0.5122
# Epoch 31: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7174 - loss: 0.5123 - val_accuracy: 0.7089 - val_loss: 0.6009
# Epoch 32/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7276 - loss: 0.5169
# Epoch 32: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7274 - loss: 0.5167 - val_accuracy: 0.6622 - val_loss: 0.7305
# Epoch 33/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7257 - loss: 0.5213
# Epoch 33: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7258 - loss: 0.5209 - val_accuracy: 0.6715 - val_loss: 0.6978
# Epoch 34/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7223 - loss: 0.5167
# Epoch 34: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7224 - loss: 0.5166 - val_accuracy: 0.6715 - val_loss: 0.7687
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7361 - loss: 0.5132
# Epoch 35: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7360 - loss: 0.5132 - val_accuracy: 0.7100 - val_loss: 0.5653
# Epoch 36/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7178 - loss: 0.5205
# Epoch 36: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7185 - loss: 0.5195 - val_accuracy: 0.7079 - val_loss: 0.6363
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7297 - loss: 0.5062
# Epoch 37: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7297 - loss: 0.5060 - val_accuracy: 0.7391 - val_loss: 0.4970
# Epoch 38/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7265 - loss: 0.5099
# Epoch 38: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7266 - loss: 0.5096 - val_accuracy: 0.6871 - val_loss: 0.6632
# Epoch 39/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7336 - loss: 0.4988
# Epoch 39: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7336 - loss: 0.4985 - val_accuracy: 0.7287 - val_loss: 0.5098
# Epoch 40/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7267 - loss: 0.5077
# Epoch 40: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7271 - loss: 0.5073 - val_accuracy: 0.5249 - val_loss: 1.0327
# Epoch 41/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7127 - loss: 0.5076
# Epoch 41: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7132 - loss: 0.5073 - val_accuracy: 0.7557 - val_loss: 0.5086
# Epoch 42/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7354 - loss: 0.4916
# Epoch 42: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7355 - loss: 0.4914 - val_accuracy: 0.6871 - val_loss: 0.5377
# Epoch 43/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7266 - loss: 0.5152
# Epoch 43: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7270 - loss: 0.5146 - val_accuracy: 0.6507 - val_loss: 0.8791
# Epoch 44/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7409 - loss: 0.5001
# Epoch 44: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7410 - loss: 0.4997 - val_accuracy: 0.6892 - val_loss: 0.7376
# Epoch 45/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7556 - loss: 0.4938
# Epoch 45: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.7552 - loss: 0.4938 - val_accuracy: 0.6809 - val_loss: 0.6189
# Epoch 46/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7329 - loss: 0.5074
# Epoch 46: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7332 - loss: 0.5069 - val_accuracy: 0.6331 - val_loss: 0.8872
# Epoch 47/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7519 - loss: 0.4884
# Epoch 47: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7522 - loss: 0.4880 - val_accuracy: 0.6684 - val_loss: 0.6165
# Epoch 48/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7421 - loss: 0.5025
# Epoch 48: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7423 - loss: 0.5019 - val_accuracy: 0.7432 - val_loss: 0.4976
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7456 - loss: 0.4940
# Epoch 49: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7456 - loss: 0.4939 - val_accuracy: 0.6715 - val_loss: 0.6145
# Epoch 50/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7499 - loss: 0.4839
# Epoch 50: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7499 - loss: 0.4836 - val_accuracy: 0.6237 - val_loss: 0.6498
# Epoch 51/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7540 - loss: 0.4761
# Epoch 51: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7537 - loss: 0.4763 - val_accuracy: 0.6871 - val_loss: 0.5453
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7338 - loss: 0.5018
# Epoch 52: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7340 - loss: 0.5015 - val_accuracy: 0.6694 - val_loss: 0.7803
# Epoch 53/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7461 - loss: 0.4845
# Epoch 53: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7468 - loss: 0.4841 - val_accuracy: 0.7110 - val_loss: 0.5154
# Epoch 54/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7509 - loss: 0.4924
# Epoch 54: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7511 - loss: 0.4916 - val_accuracy: 0.6674 - val_loss: 0.6391
# Epoch 55/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7516 - loss: 0.4831
# Epoch 55: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7518 - loss: 0.4829 - val_accuracy: 0.6268 - val_loss: 0.8213
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7509 - loss: 0.5071
# Epoch 56: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7509 - loss: 0.5066 - val_accuracy: 0.5613 - val_loss: 0.7838
# Epoch 57/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7482 - loss: 0.4818
# Epoch 57: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7484 - loss: 0.4816 - val_accuracy: 0.7443 - val_loss: 0.5049
# Epoch 58/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7520 - loss: 0.4736
# Epoch 58: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7524 - loss: 0.4733 - val_accuracy: 0.6258 - val_loss: 0.7104
# Epoch 59/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7575 - loss: 0.5473
# Epoch 59: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7575 - loss: 0.5444 - val_accuracy: 0.6798 - val_loss: 0.6361
# Epoch 60/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7476 - loss: 0.4863
# Epoch 60: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7478 - loss: 0.4860 - val_accuracy: 0.7651 - val_loss: 0.4539
# Epoch 61/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7662 - loss: 0.4796
# Epoch 61: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7662 - loss: 0.4791 - val_accuracy: 0.5873 - val_loss: 0.8222
# Epoch 62/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7521 - loss: 0.4661
# Epoch 62: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7523 - loss: 0.4660 - val_accuracy: 0.6289 - val_loss: 0.6645
# Epoch 63/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7561 - loss: 0.4638
# Epoch 63: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7563 - loss: 0.4635 - val_accuracy: 0.7193 - val_loss: 0.5239
# Epoch 64/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7514 - loss: 0.4860
# Epoch 64: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7518 - loss: 0.4854 - val_accuracy: 0.7079 - val_loss: 0.5804
# Epoch 65/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7610 - loss: 0.4626
# Epoch 65: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7612 - loss: 0.4624 - val_accuracy: 0.6892 - val_loss: 0.6210
# Epoch 66/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7783 - loss: 0.4542
# Epoch 66: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7779 - loss: 0.4546 - val_accuracy: 0.5811 - val_loss: 0.6783
# Epoch 67/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7577 - loss: 0.4776
# Epoch 67: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7584 - loss: 0.4769 - val_accuracy: 0.6819 - val_loss: 0.6241
# Epoch 68/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7682 - loss: 0.4646
# Epoch 68: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7684 - loss: 0.4642 - val_accuracy: 0.5998 - val_loss: 0.6977
# Epoch 69/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7568 - loss: 0.4736
# Epoch 69: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7570 - loss: 0.4732 - val_accuracy: 0.7713 - val_loss: 0.4952
# Epoch 70/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7632 - loss: 0.4453
# Epoch 70: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7632 - loss: 0.4456 - val_accuracy: 0.7048 - val_loss: 0.5273
# Epoch 71/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7592 - loss: 0.4559
# Epoch 71: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7595 - loss: 0.4558 - val_accuracy: 0.5800 - val_loss: 0.7969
# Epoch 72/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7720 - loss: 0.4625
# Epoch 72: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7721 - loss: 0.4623 - val_accuracy: 0.6590 - val_loss: 0.7122
# Epoch 73/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7772 - loss: 0.4594
# Epoch 73: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7771 - loss: 0.4594 - val_accuracy: 0.6902 - val_loss: 0.7380
# Epoch 74/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7802 - loss: 0.4455
# Epoch 74: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7801 - loss: 0.4457 - val_accuracy: 0.7245 - val_loss: 0.5600
# Epoch 75/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7575 - loss: 0.4582
# Epoch 75: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7578 - loss: 0.4581 - val_accuracy: 0.6486 - val_loss: 0.6831
# Epoch 76/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7610 - loss: 0.4713
# Epoch 76: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7612 - loss: 0.4705 - val_accuracy: 0.7173 - val_loss: 0.5755
# Epoch 77/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7673 - loss: 0.4452
# Epoch 77: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7680 - loss: 0.4449 - val_accuracy: 0.6611 - val_loss: 0.8950
# Epoch 78/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7685 - loss: 0.4481
# Epoch 78: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7687 - loss: 0.4481 - val_accuracy: 0.6195 - val_loss: 0.7027
# Epoch 79/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7649 - loss: 0.4612
# Epoch 79: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7653 - loss: 0.4606 - val_accuracy: 0.6985 - val_loss: 0.5926
# Epoch 80/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7729 - loss: 0.4389
# Epoch 80: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7727 - loss: 0.4391 - val_accuracy: 0.5447 - val_loss: 0.7740
# Epoch 81/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7787 - loss: 0.4550
# Epoch 81: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7790 - loss: 0.4545 - val_accuracy: 0.4667 - val_loss: 0.9152
# Epoch 82/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7645 - loss: 0.4559
# Epoch 82: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7649 - loss: 0.4554 - val_accuracy: 0.6320 - val_loss: 0.7182
# Epoch 83/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7841 - loss: 0.4610
# Epoch 83: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7841 - loss: 0.4603 - val_accuracy: 0.6507 - val_loss: 0.7904
# Epoch 84/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7922 - loss: 0.4237
# Epoch 84: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7919 - loss: 0.4241 - val_accuracy: 0.5520 - val_loss: 0.9726
# Epoch 85/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7645 - loss: 0.4535
# Epoch 85: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7651 - loss: 0.4531 - val_accuracy: 0.6216 - val_loss: 0.7575
# Epoch 86/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7846 - loss: 0.4448
# Epoch 86: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7844 - loss: 0.4443 - val_accuracy: 0.6476 - val_loss: 0.9147
# Epoch 87/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7957 - loss: 0.4255
# Epoch 87: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7958 - loss: 0.4256 - val_accuracy: 0.5551 - val_loss: 0.9257
# Epoch 88/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7855 - loss: 0.4233
# Epoch 88: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7850 - loss: 0.4235 - val_accuracy: 0.6435 - val_loss: 0.7675
# Epoch 89/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7963 - loss: 0.4229
# Epoch 89: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7958 - loss: 0.4231 - val_accuracy: 0.6091 - val_loss: 0.8083
# Epoch 90/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7782 - loss: 0.4265
# Epoch 90: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7782 - loss: 0.4266 - val_accuracy: 0.6320 - val_loss: 0.9347
# Epoch 91/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7782 - loss: 0.4370
# Epoch 91: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7782 - loss: 0.4368 - val_accuracy: 0.6289 - val_loss: 0.8172
# Epoch 92/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7613 - loss: 0.4639
# Epoch 92: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7626 - loss: 0.4622 - val_accuracy: 0.6216 - val_loss: 0.9676
# Epoch 93/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7713 - loss: 0.4373
# Epoch 93: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7713 - loss: 0.4372 - val_accuracy: 0.6091 - val_loss: 0.7459
# Epoch 94/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7995 - loss: 0.4180
# Epoch 94: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7990 - loss: 0.4183 - val_accuracy: 0.6954 - val_loss: 0.6801
# Epoch 95/100
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7981 - loss: 0.4170
# Epoch 95: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7981 - loss: 0.4171 - val_accuracy: 0.6746 - val_loss: 0.8535
# Epoch 96/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7817 - loss: 0.4426
# Epoch 96: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7819 - loss: 0.4423 - val_accuracy: 0.6684 - val_loss: 0.7293
# Epoch 97/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8058 - loss: 0.4092
# Epoch 97: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8053 - loss: 0.4099 - val_accuracy: 0.6798 - val_loss: 0.7395
# Epoch 98/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8022 - loss: 0.4188
# Epoch 98: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8020 - loss: 0.4188 - val_accuracy: 0.6497 - val_loss: 0.9534
# Epoch 99/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7980 - loss: 0.4205
# Epoch 99: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7983 - loss: 0.4202 - val_accuracy: 0.6538 - val_loss: 0.8199
# Epoch 100/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7798 - loss: 0.4251
# Epoch 100: val_accuracy did not improve from 0.80353
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7803 - loss: 0.4245 - val_accuracy: 0.5665 - val_loss: 1.2239

# %%
def plotar_historico(historico, titulo):
    plt.figure(figsize=(12, 5))
    plt.plot(historico.history['accuracy'], label='Acurácia de Treino')
    if 'val_accuracy' in historico.history:
        plt.plot(historico.history['val_accuracy'], label='Acurácia de Validação')
    plt.plot(historico.history['loss'], label='LOSS de Treino')
    if 'val_loss' in historico.history:
        plt.plot(historico.history['val_loss'], label='LOSS de Validação')
    plt.title(titulo)
    plt.xlabel('Épocas')
    plt.ylabel('Acurácia / Perda')
    plt.legend()
    plt.show()

plotar_historico(historico_rnn, f"Histórico de Treinamento - {nome_arquivo}")

# %%
plot_model(model_rnn,show_shapes=True, show_layer_names=True)

# %%
# Função para plotar a matriz de confusão
def plotar_matriz_confusao(cm, classes, title):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(title)

# Avaliar o modelo
scores = model_rnn.evaluate(X_test, y_test_cat, verbose=0)
print(f"{nome_arquivo} -> Acurácia: {scores[1]*100:.2f}%")

# Predições
y_pred = model_rnn.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_teste_classes = np.argmax(y_test_cat, axis=1)

# Gerar e plotar a matriz de confusão
cm = confusion_matrix(y_teste_classes, y_pred_classes)
plotar_matriz_confusao(cm, classes=['Classe 0', 'Classe 1'], title=f'Matriz de Confusão para {nome_arquivo}')

# Gerar relatório de classificação
print(f"Relatório de Classificação para {nome_arquivo}:\n {classification_report(y_teste_classes, y_pred_classes)}\n")
# Out:
# PETR4 -> Acurácia: 62.34%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Relatório de Classificação para PETR4:
#                precision    recall  f1-score   support
#
#            0       0.82      0.28      0.42       581
#            1       0.58      0.94      0.72       622
#
#     accuracy                           0.62      1203
#    macro avg       0.70      0.61      0.57      1203
# weighted avg       0.70      0.62      0.58      1203
