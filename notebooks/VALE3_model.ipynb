# %% [markdown]
# # Projeto Integrado Final - Deep Learning
#
# Desenvolvimento de modelo classificação utilizando Redes Neurais Convolucionais (CNN) ou Redes Neurais Recorrentes (RNN), com base na tendencia de mercado dos ultimos 15 dias, considerando o "close" da ação em base de dados suavizada.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, LSTM, Dropout, MaxPooling1D, Flatten
from tensorflow.keras.utils import to_categorical, plot_model
from keras.callbacks import ModelCheckpoint
from collections import defaultdict

# %%
df_train = pd.read_csv('../data/VALE3.SA/treino.csv')
df_test = pd.read_csv('../data/VALE3.SA/teste.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_train.head(2)
# Out:
#    Unnamed: 0        Date     Close  Smoothed_Close  Label  Past_1_Days_Close  \
# 0           1  2000-01-24  1.829122        1.752574      1           1.791015
# 1           2  2000-01-25  1.829122        1.760229      1           1.829122
#
#    Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  Past_5_Days_Close  \
# 0           1.829122           1.840554           1.848175           1.905335
# 1           1.791015           1.829122           1.840554           1.848175
#
#    Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# 0           1.867229           1.832933           1.773867           1.756719
# 1           1.905335           1.867229           1.832933           1.773867
#
#    Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# 0            1.752908            1.619535            1.562375
# 1            1.756719            1.752908            1.619535
#
#    Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# 0            1.562375            1.562375            1.600482
# 1            1.562375            1.562375            1.562375

# %%
df_test.head(2)
# Out:
#    Unnamed: 0        Date      Close  Smoothed_Close  Label  \
# 0        4809  2019-02-26  32.196571       31.573791      1
# 1        4810  2019-02-27  31.944181       31.610830      1
#
#    Past_1_Days_Close  Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  \
# 0          32.141998          32.053322          30.955091          31.241589
# 1          32.196571          32.141998          32.053322          30.955091
#
#    Past_5_Days_Close  Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  \
# 0          31.030128          30.866413          31.296162          31.146086
# 1          31.241589          31.030128          30.866413          31.296162
#
#    Past_9_Days_Close  Past_10_Days_Close  Past_11_Days_Close  \
# 0          31.030128           30.218393           28.663134
# 1          31.146086           31.030128           30.218393
#
#    Past_12_Days_Close  Past_13_Days_Close  Past_14_Days_Close  \
# 0           29.440762           28.369816           28.963266
# 1           28.663134           29.440762           28.369816
#
#    Past_15_Days_Close
# 0           30.368454
# 1           28.963266

# %%
nome_arquivo = 'VALE3'
# EDA
print(f"EDA para {nome_arquivo}:")
print(f"Descrição dos dados:\n{df_train.describe()}\n")
print(f"Contagem de valores NaN por coluna:\n{df_train.isna().sum()}\n")
print(f"Contagem dos rótulos:\n{df_train['Label'].value_counts()}\n")
# Out:
# EDA para VALE3:
# Descrição dos dados:
#         Unnamed: 0        Close  Smoothed_Close        Label  \
# count  4808.000000  4808.000000     4808.000000  4808.000000
# mean   2404.500000    14.771682       14.715974    -0.129784
# std    1388.094377     9.217010        9.165915     0.991645
# min       1.000000     1.295628        1.442017    -1.000000
# 25%    1202.750000     6.469090        6.401913    -1.000000
# 50%    2404.500000    14.931363       14.807120    -1.000000
# 75%    3606.250000    21.183798       21.286503     1.000000
# max    4808.000000    42.428528       39.779267     1.000000
#
#        Past_1_Days_Close  Past_2_Days_Close  Past_3_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean           14.765370          14.759083          14.753028
# std             9.215504           9.214017           9.212938
# min             1.295628           1.295628           1.295628
# 25%             6.463375           6.459086           6.459086
# 50%            14.924417          14.917468          14.903574
# 75%            21.170909          21.162263          21.157842
# max            42.428528          42.428528          42.428528
#
#        Past_4_Days_Close  Past_5_Days_Close  Past_6_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean           14.746915          14.740857          14.734826
# std             9.211747           9.210613           9.209546
# min             1.295628           1.295628           1.295628
# 25%             6.457448           6.452267           6.449655
# 50%            14.882737          14.871160          14.836990
# 75%            21.156904          21.154571          21.153639
# max            42.428528          42.428528          42.428528
#
#        Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean           14.728698          14.722589          14.716500
# std             9.208326           9.207175           9.206068
# min             1.295628           1.295628           1.295628
# 25%             6.443272           6.437459           6.428601
# 50%            14.800210          14.785748          14.762319
# 75%            21.152603          21.147408          21.144865
# max            42.428528          42.428528          42.428528
#
#        Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# count         4808.000000         4808.000000         4808.000000
# mean            14.710580           14.704955           14.699157
# std              9.205250            9.204985            9.204481
# min              1.295628            1.295628            1.295628
# 25%              6.428601            6.426695            6.418501
# 50%             14.747175           14.740853           14.732843
# 75%             21.142468           21.137069           21.134645
# max             42.428528           42.428528           42.428528
#
#        Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# count         4808.000000         4808.000000         4808.000000
# mean            14.693581           14.687882           14.681899
# std              9.204317            9.203963            9.203118
# min              1.295628            1.295628            1.295628
# 25%              6.409834            6.405166            6.402213
# 50%             14.714580           14.690135           14.670724
# 75%             21.133204           21.131790           21.130041
# max             42.428528           42.428528           42.428528
#
# Contagem de valores NaN por coluna:
# Unnamed: 0            0
# Date                  0
# Close                 0
# Smoothed_Close        0
# Label                 0
# Past_1_Days_Close     0
# Past_2_Days_Close     0
# Past_3_Days_Close     0
# Past_4_Days_Close     0
# Past_5_Days_Close     0
# Past_6_Days_Close     0
# Past_7_Days_Close     0
# Past_8_Days_Close     0
# Past_9_Days_Close     0
# Past_10_Days_Close    0
# Past_11_Days_Close    0
# Past_12_Days_Close    0
# Past_13_Days_Close    0
# Past_14_Days_Close    0
# Past_15_Days_Close    0
# dtype: int64
#
# Contagem dos rótulos:
# Label
# -1    2716
#  1    2092
# Name: count, dtype: int64

# %%
# COMPARAÇÃO ENTRE PREÇOS DE FECHAMENTO E PREÇOS DE FECHAMENTO SUAVIZADOS
plt.figure(figsize=(14, 7))
plt.plot(df_train['Close'], label='Close')
plt.plot(df_train['Smoothed_Close'], label='Smoothed Close')
plt.title(f'Preços de Fechamento e Suavizados - {nome_arquivo}')
plt.legend()
plt.show()

# %%
# DISTRIBUIÇÃO DOS RÓTULOS
sns.countplot(x='Label', data=df_train)
plt.title(f'Distribuição de Classes - {nome_arquivo}')
plt.show()

# %% [markdown]
# ## Treinamento de modelo de Redes Neurais Recorrentes (RNN)

# %%
## NORMALIZAÇÃO DOS DADOS

# Normalizador para as features
scaler = StandardScaler()

# Função para converter rótulos em formato categórico
def converter_para_categorico(y):
    if y.min() == -1:  # Se os rótulos forem -1 e 1
        y = (y + 1) // 2  # Converter rótulos para 0 e 1
    return to_categorical(y)

X_train = df_train.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_train = df_train['Label']

X_test = df_test.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_test = df_test['Label']

# Normalizar as features
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Converter os rótulos para formato categórico
y_train_cat = converter_para_categorico(y_train)
y_test_cat = converter_para_categorico(y_test)

# %%
# Cria e treina a rede LSTM
historicos = {}

model_rnn = Sequential([
        LSTM(70, return_sequences=True, input_shape=(X_train.shape[1], 1)),
        Dropout(0.2),
        LSTM(50, return_sequences=False, activation='relu'),
        Dense(y_train_cat.shape[1], activation='sigmoid')
    ])

# Compilando o modelo com entropia cruzada categórica para classificação binária
# A acurácia é usada como métrica para avaliação
model_rnn.compile(loss='binary_crossentropy', metrics=['accuracy'])

# Treinando o modelo com os dados
# Epochs define o número de vezes que o modelo verá todo o conjunto de dados
# Batch size é o número de amostras que o modelo vê antes de atualizar os pesos
# Verbose=1 mostra a barra de progresso do treinamento

checkpointer = ModelCheckpoint(filepath='../models/melhor_rnn_vale3.keras', verbose=1,  save_best_only=True, monitor='val_accuracy')

historico_rnn = model_rnn.fit(X_train, y_train_cat, epochs=100, batch_size=8, validation_split=0.2, verbose=1, callbacks=[checkpointer],shuffle=True)
# Out:
# Epoch 1/100
# /Users/cintia.duarte/Documents/develop/NEURAL-NETWORKS-REGRESSION/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5464 - loss: 0.6879
# Epoch 1: val_accuracy improved from -inf to 0.56445, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5466 - loss: 0.6879 - val_accuracy: 0.5644 - val_loss: 0.6934
# Epoch 2/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5752 - loss: 0.6781
# Epoch 2: val_accuracy improved from 0.56445 to 0.59563, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5751 - loss: 0.6781 - val_accuracy: 0.5956 - val_loss: 0.6461
# Epoch 3/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5859 - loss: 0.6536
# Epoch 3: val_accuracy improved from 0.59563 to 0.63617, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5859 - loss: 0.6536 - val_accuracy: 0.6362 - val_loss: 0.6322
# Epoch 4/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6373 - loss: 0.6148
# Epoch 4: val_accuracy improved from 0.63617 to 0.66216, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6374 - loss: 0.6147 - val_accuracy: 0.6622 - val_loss: 0.6685
# Epoch 5/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6468 - loss: 0.5948
# Epoch 5: val_accuracy did not improve from 0.66216
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6468 - loss: 0.5948 - val_accuracy: 0.6133 - val_loss: 0.5806
# Epoch 6/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6527 - loss: 0.5941
# Epoch 6: val_accuracy improved from 0.66216 to 0.67464, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6527 - loss: 0.5941 - val_accuracy: 0.6746 - val_loss: 0.6629
# Epoch 7/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6620 - loss: 0.5914
# Epoch 7: val_accuracy did not improve from 0.67464
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6620 - loss: 0.5914 - val_accuracy: 0.6705 - val_loss: 0.9599
# Epoch 8/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6659 - loss: 0.5845
# Epoch 8: val_accuracy improved from 0.67464 to 0.69854, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6659 - loss: 0.5845 - val_accuracy: 0.6985 - val_loss: 0.6640
# Epoch 9/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6768 - loss: 0.5674
# Epoch 9: val_accuracy improved from 0.69854 to 0.71518, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6767 - loss: 0.5675 - val_accuracy: 0.7152 - val_loss: 0.5866
# Epoch 10/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6628 - loss: 0.5778
# Epoch 10: val_accuracy did not improve from 0.71518
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6628 - loss: 0.5778 - val_accuracy: 0.6965 - val_loss: 0.7781
# Epoch 11/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6691 - loss: 0.5625
# Epoch 11: val_accuracy did not improve from 0.71518
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6692 - loss: 0.5625 - val_accuracy: 0.7079 - val_loss: 0.6066
# Epoch 12/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6783 - loss: 0.5637
# Epoch 12: val_accuracy did not improve from 0.71518
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6783 - loss: 0.5638 - val_accuracy: 0.7069 - val_loss: 0.6069
# Epoch 13/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6866 - loss: 0.5653
# Epoch 13: val_accuracy did not improve from 0.71518
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6867 - loss: 0.5653 - val_accuracy: 0.7131 - val_loss: 0.6554
# Epoch 14/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6853 - loss: 0.5579
# Epoch 14: val_accuracy improved from 0.71518 to 0.71622, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6853 - loss: 0.5579 - val_accuracy: 0.7162 - val_loss: 0.5877
# Epoch 15/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6847 - loss: 0.5489
# Epoch 15: val_accuracy improved from 0.71622 to 0.74948, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6847 - loss: 0.5489 - val_accuracy: 0.7495 - val_loss: 0.5632
# Epoch 16/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6939 - loss: 0.5554
# Epoch 16: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6938 - loss: 0.5554 - val_accuracy: 0.6996 - val_loss: 0.7319
# Epoch 17/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6890 - loss: 0.5511
# Epoch 17: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6890 - loss: 0.5511 - val_accuracy: 0.7131 - val_loss: 0.7678
# Epoch 18/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7135 - loss: 0.5401
# Epoch 18: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7134 - loss: 0.5402 - val_accuracy: 0.7225 - val_loss: 0.6749
# Epoch 19/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7006 - loss: 0.5384
# Epoch 19: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7006 - loss: 0.5384 - val_accuracy: 0.6850 - val_loss: 0.7019
# Epoch 20/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7161 - loss: 0.5256
# Epoch 20: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7160 - loss: 0.5256 - val_accuracy: 0.6476 - val_loss: 1.1355
# Epoch 21/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7054 - loss: 0.5428
# Epoch 21: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7054 - loss: 0.5426 - val_accuracy: 0.6580 - val_loss: 1.3023
# Epoch 22/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7101 - loss: 0.5269
# Epoch 22: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7101 - loss: 0.5269 - val_accuracy: 0.6944 - val_loss: 0.8917
# Epoch 23/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6928 - loss: 0.5268
# Epoch 23: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6928 - loss: 0.5268 - val_accuracy: 0.6996 - val_loss: 0.7362
# Epoch 24/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7256 - loss: 0.5065
# Epoch 24: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7256 - loss: 0.5066 - val_accuracy: 0.7318 - val_loss: 0.6059
# Epoch 25/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7050 - loss: 0.5278
# Epoch 25: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7050 - loss: 0.5278 - val_accuracy: 0.6819 - val_loss: 0.6873
# Epoch 26/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7178 - loss: 0.5967
# Epoch 26: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7178 - loss: 0.5965 - val_accuracy: 0.7173 - val_loss: 0.7918
# Epoch 27/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6974 - loss: 0.5371
# Epoch 27: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6976 - loss: 0.5370 - val_accuracy: 0.6944 - val_loss: 1.5490
# Epoch 28/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7220 - loss: 0.5046
# Epoch 28: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7220 - loss: 0.5046 - val_accuracy: 0.6715 - val_loss: 1.4407
# Epoch 29/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7382 - loss: 0.4913
# Epoch 29: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7382 - loss: 0.4914 - val_accuracy: 0.7370 - val_loss: 0.6830
# Epoch 30/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7287 - loss: 0.5160
# Epoch 30: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7287 - loss: 0.5159 - val_accuracy: 0.6933 - val_loss: 0.9176
# Epoch 31/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7293 - loss: 0.4959
# Epoch 31: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7293 - loss: 0.4959 - val_accuracy: 0.7214 - val_loss: 0.7342
# Epoch 32/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7390 - loss: 0.4984
# Epoch 32: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7390 - loss: 0.4984 - val_accuracy: 0.6726 - val_loss: 1.0835
# Epoch 33/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7221 - loss: 0.5021
# Epoch 33: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7221 - loss: 0.5021 - val_accuracy: 0.6611 - val_loss: 1.5121
# Epoch 34/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7400 - loss: 0.4973
# Epoch 34: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7400 - loss: 0.4972 - val_accuracy: 0.6985 - val_loss: 0.8407
# Epoch 35/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7534 - loss: 0.4786
# Epoch 35: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7532 - loss: 0.4788 - val_accuracy: 0.6840 - val_loss: 0.8475
# Epoch 36/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7378 - loss: 0.5048
# Epoch 36: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7378 - loss: 0.5048 - val_accuracy: 0.6559 - val_loss: 0.9115
# Epoch 37/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7318 - loss: 0.4839
# Epoch 37: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7318 - loss: 0.4839 - val_accuracy: 0.5748 - val_loss: 2.1316
# Epoch 38/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7353 - loss: 0.5062
# Epoch 38: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7353 - loss: 0.5061 - val_accuracy: 0.7297 - val_loss: 0.6695
# Epoch 39/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7433 - loss: 0.5343
# Epoch 39: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7433 - loss: 0.5339 - val_accuracy: 0.7214 - val_loss: 0.9816
# Epoch 40/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7497 - loss: 0.4723
# Epoch 40: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7496 - loss: 0.4726 - val_accuracy: 0.7245 - val_loss: 0.6705
# Epoch 41/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7431 - loss: 0.4838
# Epoch 41: val_accuracy improved from 0.74948 to 0.75052, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7431 - loss: 0.4838 - val_accuracy: 0.7505 - val_loss: 0.5792
# Epoch 42/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7265 - loss: 0.4945
# Epoch 42: val_accuracy did not improve from 0.75052
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7265 - loss: 0.4949 - val_accuracy: 0.7266 - val_loss: 0.9374
# Epoch 43/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7411 - loss: 0.4910
# Epoch 43: val_accuracy did not improve from 0.75052
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7411 - loss: 0.4909 - val_accuracy: 0.7058 - val_loss: 0.7698
# Epoch 44/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7417 - loss: 0.5043
# Epoch 44: val_accuracy did not improve from 0.75052
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7418 - loss: 0.5043 - val_accuracy: 0.7277 - val_loss: 2.0214
# Epoch 45/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7399 - loss: 0.4882
# Epoch 45: val_accuracy did not improve from 0.75052
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7399 - loss: 0.4882 - val_accuracy: 0.7006 - val_loss: 0.6598
# Epoch 46/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7695 - loss: 0.4856
# Epoch 46: val_accuracy did not improve from 0.75052
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7694 - loss: 0.4855 - val_accuracy: 0.7214 - val_loss: 0.6159
# Epoch 47/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7669 - loss: 0.4718
# Epoch 47: val_accuracy did not improve from 0.75052
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7668 - loss: 0.4719 - val_accuracy: 0.7308 - val_loss: 0.5947
# Epoch 48/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7533 - loss: 0.5127
# Epoch 48: val_accuracy improved from 0.75052 to 0.76715, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7533 - loss: 0.5126 - val_accuracy: 0.7672 - val_loss: 0.4950
# Epoch 49/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7541 - loss: 0.5030
# Epoch 49: val_accuracy did not improve from 0.76715
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7542 - loss: 0.5028 - val_accuracy: 0.7391 - val_loss: 0.5291
# Epoch 50/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7432 - loss: 0.4816
# Epoch 50: val_accuracy improved from 0.76715 to 0.81913, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7778 - loss: 0.4697
# Epoch 95: val_accuracy did not improve from 0.81913
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7778 - loss: 0.4698 - val_accuracy: 0.7266 - val_loss: 35.2464
# Epoch 96/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7823 - loss: 0.4403
# Epoch 96: val_accuracy did not improve from 0.81913
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7823 - loss: 0.4403 - val_accuracy: 0.6538 - val_loss: 260.1028
# Epoch 97/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7976 - loss: 1.1366
# Epoch 97: val_accuracy did not improve from 0.81913
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7975 - loss: 1.1335 - val_accuracy: 0.6601 - val_loss: 8.2885
# Epoch 98/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7802 - loss: 0.5103
# Epoch 98: val_accuracy did not improve from 0.81913
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7802 - loss: 0.5105 - val_accuracy: 0.6164 - val_loss: 108.4713
# Epoch 99/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7830 - loss: 1.8189
# Epoch 99: val_accuracy did not improve from 0.81913
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7830 - loss: 1.8230 - val_accuracy: 0.6559 - val_loss: 2981.2844
# Epoch 100/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7686 - loss: 19.0514
# Epoch 100: val_accuracy did not improve from 0.81913
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7686 - loss: 18.8938 - val_accuracy: 0.6902 - val_loss: 82.6566

# %%
def plotar_historico(historico, titulo):
    plt.figure(figsize=(12, 5))
    plt.plot(historico.history['accuracy'], label='Acurácia de Treino')
    if 'val_accuracy' in historico.history:
        plt.plot(historico.history['val_accuracy'], label='Acurácia de Validação')
    plt.plot(historico.history['loss'], label='Perda de Treino')
    if 'val_loss' in historico.history:
        plt.plot(historico.history['val_loss'], label='Perda de Validação')
    plt.title(titulo)
    plt.xlabel('Épocas')
    plt.ylabel('Acurácia / Perda')
    plt.legend()
    plt.show()

plotar_historico(historico_rnn, f"Histórico de Treinamento - {nome_arquivo}")

# %%
plot_model(model_rnn,show_shapes=True, show_layer_names=True)

# %%
# Função para plotar a matriz de confusão
def plotar_matriz_confusao(cm, classes, title):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(title)

# Avaliar o modelo
scores = model_rnn.evaluate(X_test, y_test_cat, verbose=0)
print(f"{nome_arquivo} -> Acurácia: {scores[1]*100:.2f}%")

# Predições
y_pred = model_rnn.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_teste_classes = np.argmax(y_test_cat, axis=1)

# Gerar e plotar a matriz de confusão
cm = confusion_matrix(y_teste_classes, y_pred_classes)
plotar_matriz_confusao(cm, classes=['Classe 0', 'Classe 1'], title=f'Matriz de Confusão para {nome_arquivo}')

# Gerar relatório de classificação
print(f"Relatório de Classificação para {nome_arquivo}:\n {classification_report(y_teste_classes, y_pred_classes)}\n")
# Out:
# VALE3 -> Acurácia: 48.79%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Relatório de Classificação para VALE3:
#                precision    recall  f1-score   support
#
#            0       0.49      0.80      0.61       601
#            1       0.44      0.16      0.23       602
#
#     accuracy                           0.48      1203
#    macro avg       0.47      0.48      0.42      1203
# weighted avg       0.47      0.48      0.42      1203
