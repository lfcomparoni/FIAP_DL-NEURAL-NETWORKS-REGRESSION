# %% [markdown]
# # Projeto Integrado Final - Deep Learning
#
# Desenvolvimento de modelo classificação utilizando Redes Neurais Convolucionais (CNN) ou Redes Neurais Recorrentes (RNN), com base na tendencia de mercado dos ultimos 15 dias, considerando o "close" da ação em base de dados suavizada.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, LSTM, Dropout, MaxPooling1D, Flatten
from tensorflow.keras.utils import to_categorical, plot_model
from keras.callbacks import ModelCheckpoint
from collections import defaultdict

# %%
df_train = pd.read_csv('../data/VALE3.SA/treino.csv')
df_test = pd.read_csv('../data/VALE3.SA/teste.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_train.head(2)
# Out:
#    Unnamed: 0        Date     Close  Smoothed_Close  Label  Past_1_Days_Close  \
# 0           1  2000-01-24  1.829122        1.752574      1           1.791015
# 1           2  2000-01-25  1.829122        1.760229      1           1.829122
#
#    Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  Past_5_Days_Close  \
# 0           1.829122           1.840554           1.848175           1.905335
# 1           1.791015           1.829122           1.840554           1.848175
#
#    Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# 0           1.867229           1.832933           1.773867           1.756719
# 1           1.905335           1.867229           1.832933           1.773867
#
#    Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# 0            1.752908            1.619535            1.562375
# 1            1.756719            1.752908            1.619535
#
#    Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# 0            1.562375            1.562375            1.600482
# 1            1.562375            1.562375            1.562375

# %%
df_test.head(2)
# Out:
#    Unnamed: 0        Date      Close  Smoothed_Close  Label  \
# 0        4809  2019-02-26  32.196571       31.573791      1
# 1        4810  2019-02-27  31.944181       31.610830      1
#
#    Past_1_Days_Close  Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  \
# 0          32.141998          32.053322          30.955091          31.241589
# 1          32.196571          32.141998          32.053322          30.955091
#
#    Past_5_Days_Close  Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  \
# 0          31.030128          30.866413          31.296162          31.146086
# 1          31.241589          31.030128          30.866413          31.296162
#
#    Past_9_Days_Close  Past_10_Days_Close  Past_11_Days_Close  \
# 0          31.030128           30.218393           28.663134
# 1          31.146086           31.030128           30.218393
#
#    Past_12_Days_Close  Past_13_Days_Close  Past_14_Days_Close  \
# 0           29.440762           28.369816           28.963266
# 1           28.663134           29.440762           28.369816
#
#    Past_15_Days_Close
# 0           30.368454
# 1           28.963266

# %%
nome_arquivo = 'VALE3'
# EDA
print(f"EDA para {nome_arquivo}:")
print(f"Descrição dos dados:\n{df_train.describe()}\n")
print(f"Contagem de valores NaN por coluna:\n{df_train.isna().sum()}\n")
print(f"Contagem dos rótulos:\n{df_train['Label'].value_counts()}\n")
# Out:
# EDA para VALE3:
# Descrição dos dados:
#         Unnamed: 0        Close  Smoothed_Close        Label  \
# count  4808.000000  4808.000000     4808.000000  4808.000000
# mean   2404.500000    14.771682       14.715974    -0.129784
# std    1388.094377     9.217010        9.165915     0.991645
# min       1.000000     1.295628        1.442017    -1.000000
# 25%    1202.750000     6.469090        6.401913    -1.000000
# 50%    2404.500000    14.931363       14.807120    -1.000000
# 75%    3606.250000    21.183798       21.286503     1.000000
# max    4808.000000    42.428528       39.779267     1.000000
#
#        Past_1_Days_Close  Past_2_Days_Close  Past_3_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean           14.765370          14.759083          14.753028
# std             9.215504           9.214017           9.212938
# min             1.295628           1.295628           1.295628
# 25%             6.463375           6.459086           6.459086
# 50%            14.924417          14.917468          14.903574
# 75%            21.170909          21.162263          21.157842
# max            42.428528          42.428528          42.428528
#
#        Past_4_Days_Close  Past_5_Days_Close  Past_6_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean           14.746915          14.740857          14.734826
# std             9.211747           9.210613           9.209546
# min             1.295628           1.295628           1.295628
# 25%             6.457448           6.452267           6.449655
# 50%            14.882737          14.871160          14.836990
# 75%            21.156904          21.154571          21.153639
# max            42.428528          42.428528          42.428528
#
#        Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean           14.728698          14.722589          14.716500
# std             9.208326           9.207175           9.206068
# min             1.295628           1.295628           1.295628
# 25%             6.443272           6.437459           6.428601
# 50%            14.800210          14.785748          14.762319
# 75%            21.152603          21.147408          21.144865
# max            42.428528          42.428528          42.428528
#
#        Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# count         4808.000000         4808.000000         4808.000000
# mean            14.710580           14.704955           14.699157
# std              9.205250            9.204985            9.204481
# min              1.295628            1.295628            1.295628
# 25%              6.428601            6.426695            6.418501
# 50%             14.747175           14.740853           14.732843
# 75%             21.142468           21.137069           21.134645
# max             42.428528           42.428528           42.428528
#
#        Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# count         4808.000000         4808.000000         4808.000000
# mean            14.693581           14.687882           14.681899
# std              9.204317            9.203963            9.203118
# min              1.295628            1.295628            1.295628
# 25%              6.409834            6.405166            6.402213
# 50%             14.714580           14.690135           14.670724
# 75%             21.133204           21.131790           21.130041
# max             42.428528           42.428528           42.428528
#
# Contagem de valores NaN por coluna:
# Unnamed: 0            0
# Date                  0
# Close                 0
# Smoothed_Close        0
# Label                 0
# Past_1_Days_Close     0
# Past_2_Days_Close     0
# Past_3_Days_Close     0
# Past_4_Days_Close     0
# Past_5_Days_Close     0
# Past_6_Days_Close     0
# Past_7_Days_Close     0
# Past_8_Days_Close     0
# Past_9_Days_Close     0
# Past_10_Days_Close    0
# Past_11_Days_Close    0
# Past_12_Days_Close    0
# Past_13_Days_Close    0
# Past_14_Days_Close    0
# Past_15_Days_Close    0
# dtype: int64
#
# Contagem dos rótulos:
# Label
# -1    2716
#  1    2092
# Name: count, dtype: int64

# %%
# COMPARAÇÃO ENTRE PREÇOS DE FECHAMENTO E PREÇOS DE FECHAMENTO SUAVIZADOS
plt.figure(figsize=(14, 7))
plt.plot(df_train['Close'], label='Close')
plt.plot(df_train['Smoothed_Close'], label='Smoothed Close')
plt.title(f'Preços de Fechamento e Suavizados - {nome_arquivo}')
plt.legend()
plt.show()

# %%
# DISTRIBUIÇÃO DOS RÓTULOS
sns.countplot(x='Label', data=df_train)
plt.title(f'Distribuição de Classes - {nome_arquivo}')
plt.show()

# %% [markdown]
# ## Treinamento de modelo de Redes Neurais Recorrentes (RNN)

# %%
## NORMALIZAÇÃO DOS DADOS

# Normalizador para as features
scaler = StandardScaler()

# Função para converter rótulos em formato categórico
def converter_para_categorico(y):
    if y.min() == -1:  # Se os rótulos forem -1 e 1
        y = (y + 1) // 2  # Converter rótulos para 0 e 1
    return to_categorical(y)

X_train = df_train.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_train = df_train['Label']

X_test = df_test.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_test = df_test['Label']

# Normalizar as features
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Converter os rótulos para formato categórico
y_train_cat = converter_para_categorico(y_train)
y_test_cat = converter_para_categorico(y_test)

# %%
# Cria e treina a rede LSTM
historicos = {}

model_rnn = Sequential([
        # Adicionando a primeira camada LSTM
        # 50 unidades referem-se ao número de neurônios na camada
        # return_sequences=True para passar sequências para a próxima camada LSTM
        # input_shape define o formato esperado dos dados de entrada       
        LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)),
        # Segunda camada LSTM com 50 unidades
        LSTM(50),
        # Camada densa com 50 neurônios e função de ativação ReLU
        Dense(50, activation='relu'),
        # Camada de saída densa com uma unidade por classe esperada
        # Com funcao de ativacao sigmoid para classificação binária
        Dense(y_train_cat.shape[1], activation='sigmoid')
    ])

# Compilando o modelo com entropia cruzada categórica para classificação binária
# A acurácia é usada como métrica para avaliação
model_rnn.compile(loss='binary_crossentropy', metrics=['accuracy'])

# Treinando o modelo com os dados
# Epochs define o número de vezes que o modelo verá todo o conjunto de dados
# Batch size é o número de amostras que o modelo vê antes de atualizar os pesos
# Verbose=1 mostra a barra de progresso do treinamento

checkpointer = ModelCheckpoint(filepath='../models/melhor_rnn_vale3.keras', verbose=1,  save_best_only=True, monitor='val_accuracy')

historico_rnn = model_rnn.fit(X_train, y_train_cat, epochs=100, batch_size=8, validation_split=0.2, verbose=1, callbacks=[checkpointer],shuffle=True)
# Out:
# Epoch 1/100
# /Users/cintia.duarte/Documents/develop/NEURAL-NETWORKS-REGRESSION/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5453 - loss: 0.6875
# Epoch 1: val_accuracy improved from -inf to 0.56445, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5454 - loss: 0.6875 - val_accuracy: 0.5644 - val_loss: 0.6852
# Epoch 2/100
# 474/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5539 - loss: 0.6831
# Epoch 2: val_accuracy improved from 0.56445 to 0.64761, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5541 - loss: 0.6829 - val_accuracy: 0.6476 - val_loss: 0.6133
# Epoch 3/100
# 473/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5846 - loss: 0.6458
# Epoch 3: val_accuracy did not improve from 0.64761
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5852 - loss: 0.6454 - val_accuracy: 0.5925 - val_loss: 0.9592
# Epoch 4/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6549 - loss: 0.6078
# Epoch 4: val_accuracy improved from 0.64761 to 0.71206, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6550 - loss: 0.6075 - val_accuracy: 0.7121 - val_loss: 0.7213
# Epoch 5/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6715 - loss: 0.5750
# Epoch 5: val_accuracy improved from 0.71206 to 0.74948, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6715 - loss: 0.5750 - val_accuracy: 0.7495 - val_loss: 0.5636
# Epoch 6/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6751 - loss: 0.5675
# Epoch 6: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6751 - loss: 0.5675 - val_accuracy: 0.7225 - val_loss: 0.5736
# Epoch 7/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6827 - loss: 0.5592
# Epoch 7: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6825 - loss: 0.5593 - val_accuracy: 0.7017 - val_loss: 0.5640
# Epoch 8/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6718 - loss: 0.5641
# Epoch 8: val_accuracy did not improve from 0.74948
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6718 - loss: 0.5641 - val_accuracy: 0.6414 - val_loss: 0.7334
# Epoch 9/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6762 - loss: 0.5656
# Epoch 9: val_accuracy improved from 0.74948 to 0.76195, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6762 - loss: 0.5655 - val_accuracy: 0.7620 - val_loss: 0.5781
# Epoch 10/100
# 474/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6818 - loss: 0.5626
# Epoch 10: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6819 - loss: 0.5625 - val_accuracy: 0.6601 - val_loss: 0.6719
# Epoch 11/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6690 - loss: 0.5597
# Epoch 11: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6692 - loss: 0.5596 - val_accuracy: 0.6746 - val_loss: 0.6482
# Epoch 12/100
# 472/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7037 - loss: 0.5385
# Epoch 12: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7035 - loss: 0.5388 - val_accuracy: 0.6861 - val_loss: 0.6401
# Epoch 13/100
# 474/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6909 - loss: 0.5488
# Epoch 13: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6909 - loss: 0.5488 - val_accuracy: 0.6684 - val_loss: 0.6464
# Epoch 14/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6899 - loss: 0.5453
# Epoch 14: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6899 - loss: 0.5453 - val_accuracy: 0.7037 - val_loss: 0.5444
# Epoch 15/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6834 - loss: 0.5415
# Epoch 15: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6835 - loss: 0.5416 - val_accuracy: 0.6933 - val_loss: 0.6770
# Epoch 16/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7011 - loss: 0.5377
# Epoch 16: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7011 - loss: 0.5377 - val_accuracy: 0.7505 - val_loss: 0.4778
# Epoch 17/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7053 - loss: 0.5356
# Epoch 17: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7052 - loss: 0.5356 - val_accuracy: 0.6746 - val_loss: 0.8860
# Epoch 18/100
# 473/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7021 - loss: 0.5483
# Epoch 18: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7022 - loss: 0.5481 - val_accuracy: 0.7100 - val_loss: 0.6431
# Epoch 19/100
# 469/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7099 - loss: 0.5328
# Epoch 19: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7098 - loss: 0.5328 - val_accuracy: 0.7370 - val_loss: 0.4980
# Epoch 20/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7096 - loss: 0.5369
# Epoch 20: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7096 - loss: 0.5368 - val_accuracy: 0.7339 - val_loss: 0.6129
# Epoch 21/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6956 - loss: 0.5443
# Epoch 21: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6956 - loss: 0.5442 - val_accuracy: 0.7204 - val_loss: 0.6169
# Epoch 22/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7059 - loss: 0.5252
# Epoch 22: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7059 - loss: 0.5253 - val_accuracy: 0.6757 - val_loss: 0.6806
# Epoch 23/100
# 468/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7102 - loss: 0.5117
# Epoch 23: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7099 - loss: 0.5120 - val_accuracy: 0.7152 - val_loss: 0.5978
# Epoch 24/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7039 - loss: 0.5357
# Epoch 24: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7039 - loss: 0.5355 - val_accuracy: 0.6996 - val_loss: 0.7514
# Epoch 25/100
# 470/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7174 - loss: 0.5186
# Epoch 25: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7174 - loss: 0.5185 - val_accuracy: 0.6840 - val_loss: 0.7127
# Epoch 26/100
# 475/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7155 - loss: 0.5127
# Epoch 26: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7156 - loss: 0.5127 - val_accuracy: 0.7360 - val_loss: 0.5600
# Epoch 27/100
# 470/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7116 - loss: 0.5290
# Epoch 27: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7119 - loss: 0.5286 - val_accuracy: 0.7017 - val_loss: 0.6593
# Epoch 28/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7235 - loss: 0.5030
# Epoch 28: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7235 - loss: 0.5030 - val_accuracy: 0.7037 - val_loss: 0.7687
# Epoch 29/100
# 470/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7230 - loss: 0.5043
# Epoch 29: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7232 - loss: 0.5042 - val_accuracy: 0.7173 - val_loss: 0.6348
# Epoch 30/100
# 469/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7392 - loss: 0.4894
# Epoch 30: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7389 - loss: 0.4896 - val_accuracy: 0.7162 - val_loss: 0.7726
# Epoch 31/100
# 469/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7387 - loss: 0.4946
# Epoch 31: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7385 - loss: 0.4945 - val_accuracy: 0.6819 - val_loss: 1.0097
# Epoch 32/100
# 473/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7282 - loss: 0.4949
# Epoch 32: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7283 - loss: 0.4948 - val_accuracy: 0.7536 - val_loss: 0.6560
# Epoch 33/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7362 - loss: 0.4888
# Epoch 33: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7362 - loss: 0.4888 - val_accuracy: 0.7069 - val_loss: 0.8028
# Epoch 34/100
# 470/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7406 - loss: 0.4797
# Epoch 34: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7405 - loss: 0.4798 - val_accuracy: 0.7453 - val_loss: 0.7592
# Epoch 35/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7387 - loss: 0.4753
# Epoch 35: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7388 - loss: 0.4754 - val_accuracy: 0.7349 - val_loss: 0.7528
# Epoch 36/100
# 470/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7376 - loss: 0.4798
# Epoch 36: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7375 - loss: 0.4799 - val_accuracy: 0.6996 - val_loss: 0.8002
# Epoch 37/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7463 - loss: 0.4698
# Epoch 37: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7463 - loss: 0.4698 - val_accuracy: 0.7100 - val_loss: 1.1572
# Epoch 38/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7370 - loss: 0.4780
# Epoch 38: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7372 - loss: 0.4779 - val_accuracy: 0.6996 - val_loss: 0.8136
# Epoch 39/100
# 469/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7389 - loss: 0.4844
# Epoch 39: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7391 - loss: 0.4841 - val_accuracy: 0.6985 - val_loss: 1.0851
# Epoch 40/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7528 - loss: 0.4700
# Epoch 40: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7528 - loss: 0.4700 - val_accuracy: 0.6694 - val_loss: 1.2205
# Epoch 41/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7476 - loss: 0.4804
# Epoch 41: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7476 - loss: 0.4803 - val_accuracy: 0.6933 - val_loss: 0.7974
# Epoch 42/100
# 470/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7461 - loss: 0.4750
# Epoch 42: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7461 - loss: 0.4749 - val_accuracy: 0.7131 - val_loss: 0.8722
# Epoch 43/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7512 - loss: 0.4555
# Epoch 43: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7512 - loss: 0.4556 - val_accuracy: 0.6861 - val_loss: 1.0748
# Epoch 44/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7670 - loss: 0.4481
# Epoch 44: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7669 - loss: 0.4482 - val_accuracy: 0.6944 - val_loss: 0.7581
# Epoch 45/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7560 - loss: 0.4665
# Epoch 45: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7560 - loss: 0.4664 - val_accuracy: 0.6861 - val_loss: 0.8198
# Epoch 46/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7631 - loss: 0.4554
# Epoch 46: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7631 - loss: 0.4554 - val_accuracy: 0.6913 - val_loss: 0.8267
# Epoch 47/100
# 468/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7695 - loss: 0.4516
# Epoch 47: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7693 - loss: 0.4517 - val_accuracy: 0.6642 - val_loss: 1.2901
# Epoch 48/100
# 472/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7668 - loss: 0.4567
# Epoch 48: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7666 - loss: 0.4567 - val_accuracy: 0.7349 - val_loss: 1.2350
# Epoch 49/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7619 - loss: 0.4527
# Epoch 49: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7619 - loss: 0.4527 - val_accuracy: 0.6736 - val_loss: 1.0396
# Epoch 50/100
# 474/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7587 - loss: 0.4504
# Epoch 50: val_accuracy did not improve from 0.76195
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7587 - loss: 0.4505 - val_accuracy: 0.6861 - val_loss: 0.9861
# Epoch 51/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7600 - loss: 0.4529
# Epoch 51: val_accuracy improved from 0.76195 to 0.77131, saving model to ../models/melhor_rnn_vale3.keras
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7600 - loss: 0.4529 - val_accuracy: 0.7713 - val_loss: 0.9210
# Epoch 52/100
# 472/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7586 - loss: 0.4561
# Epoch 52: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7587 - loss: 0.4561 - val_accuracy: 0.6902 - val_loss: 1.3161
# Epoch 53/100
# 475/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7673 - loss: 0.4361
# Epoch 53: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7673 - loss: 0.4362 - val_accuracy: 0.6881 - val_loss: 1.4200
# Epoch 54/100
# 472/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7717 - loss: 0.4364
# Epoch 54: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7716 - loss: 0.4366 - val_accuracy: 0.6933 - val_loss: 1.2747
# Epoch 55/100
# 470/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7637 - loss: 0.4487
# Epoch 55: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7637 - loss: 0.4485 - val_accuracy: 0.6694 - val_loss: 1.0958
# Epoch 56/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7748 - loss: 0.4294
# Epoch 56: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7747 - loss: 0.4296 - val_accuracy: 0.7017 - val_loss: 1.3973
# Epoch 57/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7778 - loss: 0.4473
# Epoch 57: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7777 - loss: 0.4472 - val_accuracy: 0.6861 - val_loss: 1.3109
# Epoch 58/100
# 474/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7609 - loss: 0.4476
# Epoch 58: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7610 - loss: 0.4475 - val_accuracy: 0.7484 - val_loss: 1.3023
# Epoch 59/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7629 - loss: 0.4532
# Epoch 59: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7629 - loss: 0.4532 - val_accuracy: 0.7214 - val_loss: 1.7045
# Epoch 60/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7690 - loss: 0.4356
# Epoch 60: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7689 - loss: 0.4356 - val_accuracy: 0.6819 - val_loss: 1.8956
# Epoch 61/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7677 - loss: 0.4395
# Epoch 61: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7679 - loss: 0.4395 - val_accuracy: 0.6881 - val_loss: 1.4442
# Epoch 62/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7701 - loss: 0.4415
# Epoch 62: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7702 - loss: 0.4414 - val_accuracy: 0.6975 - val_loss: 1.6976
# Epoch 63/100
# 473/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7676 - loss: 0.4348
# Epoch 63: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7677 - loss: 0.4348 - val_accuracy: 0.6809 - val_loss: 1.9577
# Epoch 64/100
# 473/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7783 - loss: 0.4300
# Epoch 64: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7784 - loss: 0.4299 - val_accuracy: 0.7266 - val_loss: 1.5637
# Epoch 65/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7749 - loss: 0.4459
# Epoch 65: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7749 - loss: 0.4458 - val_accuracy: 0.7557 - val_loss: 1.7610
# Epoch 66/100
# 472/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7780 - loss: 0.4448
# Epoch 66: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7781 - loss: 0.4446 - val_accuracy: 0.6705 - val_loss: 2.0000
# Epoch 67/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7937 - loss: 0.4160
# Epoch 67: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7937 - loss: 0.4160 - val_accuracy: 0.6944 - val_loss: 1.5394
# Epoch 68/100
# 469/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7712 - loss: 0.4346
# Epoch 68: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7714 - loss: 0.4343 - val_accuracy: 0.6476 - val_loss: 2.0884
# Epoch 69/100
# 477/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7753 - loss: 0.4196
# Epoch 69: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7753 - loss: 0.4196 - val_accuracy: 0.7089 - val_loss: 1.8211
# Epoch 70/100
# 472/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7843 - loss: 0.4363
# Epoch 70: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7843 - loss: 0.4361 - val_accuracy: 0.6871 - val_loss: 2.0411
# Epoch 71/100
# 468/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7675 - loss: 0.4387
# Epoch 71: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7678 - loss: 0.4384 - val_accuracy: 0.6944 - val_loss: 2.1012
# Epoch 72/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7752 - loss: 0.4246
# Epoch 72: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7753 - loss: 0.4246 - val_accuracy: 0.6653 - val_loss: 2.4762
# Epoch 73/100
# 470/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7925 - loss: 0.4022
# Epoch 73: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7924 - loss: 0.4026 - val_accuracy: 0.6778 - val_loss: 2.2805
# Epoch 74/100
# 469/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7886 - loss: 0.4157
# Epoch 74: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7884 - loss: 0.4158 - val_accuracy: 0.7131 - val_loss: 1.9599
# Epoch 75/100
# 475/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7748 - loss: 0.4239
# Epoch 75: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7749 - loss: 0.4239 - val_accuracy: 0.7048 - val_loss: 2.2898
# Epoch 76/100
# 474/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7776 - loss: 0.4222
# Epoch 76: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7777 - loss: 0.4221 - val_accuracy: 0.7069 - val_loss: 1.9958
# Epoch 77/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7896 - loss: 0.4051
# Epoch 77: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7895 - loss: 0.4052 - val_accuracy: 0.7162 - val_loss: 1.7018
# Epoch 78/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7773 - loss: 0.4175
# Epoch 78: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7773 - loss: 0.4175 - val_accuracy: 0.6965 - val_loss: 2.2781
# Epoch 79/100
# 475/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7891 - loss: 0.3980
# Epoch 79: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7890 - loss: 0.3981 - val_accuracy: 0.7328 - val_loss: 2.1201
# Epoch 80/100
# 468/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8015 - loss: 0.4038
# Epoch 80: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8013 - loss: 0.4040 - val_accuracy: 0.7100 - val_loss: 2.4335
# Epoch 81/100
# 467/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7935 - loss: 0.4091
# Epoch 81: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7934 - loss: 0.4092 - val_accuracy: 0.7193 - val_loss: 2.5002
# Epoch 82/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7875 - loss: 0.4154
# Epoch 82: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7875 - loss: 0.4153 - val_accuracy: 0.6871 - val_loss: 2.1713
# Epoch 83/100
# 474/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.4119
# Epoch 83: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7939 - loss: 0.4118 - val_accuracy: 0.7183 - val_loss: 2.3654
# Epoch 84/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7850 - loss: 0.4100
# Epoch 84: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7850 - loss: 0.4100 - val_accuracy: 0.6902 - val_loss: 2.4611
# Epoch 85/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7867 - loss: 0.4022
# Epoch 85: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7869 - loss: 0.4022 - val_accuracy: 0.6965 - val_loss: 2.8512
# Epoch 86/100
# 469/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7951 - loss: 0.4028
# Epoch 86: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7952 - loss: 0.4028 - val_accuracy: 0.6985 - val_loss: 3.2584
# Epoch 87/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7929 - loss: 0.3972
# Epoch 87: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7929 - loss: 0.3973 - val_accuracy: 0.7100 - val_loss: 2.7268
# Epoch 88/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8002 - loss: 0.3891
# Epoch 88: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8001 - loss: 0.3893 - val_accuracy: 0.7058 - val_loss: 2.1842
# Epoch 89/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7869 - loss: 0.4095
# Epoch 89: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7870 - loss: 0.4095 - val_accuracy: 0.6809 - val_loss: 3.1334
# Epoch 90/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8037 - loss: 0.3858
# Epoch 90: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8036 - loss: 0.3860 - val_accuracy: 0.7183 - val_loss: 2.5033
# Epoch 91/100
# 476/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7964 - loss: 0.3893
# Epoch 91: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7964 - loss: 0.3894 - val_accuracy: 0.7089 - val_loss: 2.3178
# Epoch 92/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7971 - loss: 0.3974
# Epoch 92: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7970 - loss: 0.3976 - val_accuracy: 0.7193 - val_loss: 2.6185
# Epoch 93/100
# 469/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7903 - loss: 0.3979
# Epoch 93: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7902 - loss: 0.3980 - val_accuracy: 0.6985 - val_loss: 2.4542
# Epoch 94/100
# 478/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8011 - loss: 0.3916
# Epoch 94: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8011 - loss: 0.3916 - val_accuracy: 0.6715 - val_loss: 4.2111
# Epoch 95/100
# 479/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7993 - loss: 0.4009
# Epoch 95: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7993 - loss: 0.4008 - val_accuracy: 0.6788 - val_loss: 3.0109
# Epoch 96/100
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7958 - loss: 0.4004
# Epoch 96: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7958 - loss: 0.4004 - val_accuracy: 0.6923 - val_loss: 2.9735
# Epoch 97/100
# 471/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7999 - loss: 0.3936
# Epoch 97: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7999 - loss: 0.3936 - val_accuracy: 0.7037 - val_loss: 2.7144
# Epoch 98/100
# 472/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8013 - loss: 0.3966
# Epoch 98: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8012 - loss: 0.3965 - val_accuracy: 0.7121 - val_loss: 2.6054
# Epoch 99/100
# 468/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8008 - loss: 0.3957
# Epoch 99: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8007 - loss: 0.3955 - val_accuracy: 0.7100 - val_loss: 3.0665
# Epoch 100/100
# 480/481 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.3896
# Epoch 100: val_accuracy did not improve from 0.77131
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8019 - loss: 0.3897 - val_accuracy: 0.7069 - val_loss: 2.4342

# %%
def plotar_historico(historico, titulo):
    plt.figure(figsize=(12, 5))
    plt.plot(historico.history['accuracy'], label='Acurácia de Treino')
    if 'val_accuracy' in historico.history:
        plt.plot(historico.history['val_accuracy'], label='Acurácia de Validação')
    plt.plot(historico.history['loss'], label='Perda de Treino')
    if 'val_loss' in historico.history:
        plt.plot(historico.history['val_loss'], label='Perda de Validação')
    plt.title(titulo)
    plt.xlabel('Épocas')
    plt.ylabel('Acurácia / Perda')
    plt.legend()
    plt.show()

plotar_historico(historico_rnn, f"Histórico de Treinamento - {nome_arquivo}")

# %%
plot_model(model_rnn,show_shapes=True, show_layer_names=True)

# %%
# Função para plotar a matriz de confusão
def plotar_matriz_confusao(cm, classes, title):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(title)

# Avaliar o modelo
scores = model_rnn.evaluate(X_test, y_test_cat, verbose=0)
print(f"{nome_arquivo} -> Acurácia: {scores[1]*100:.2f}%")

# Predições
y_pred = model_rnn.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_teste_classes = np.argmax(y_test_cat, axis=1)

# Gerar e plotar a matriz de confusão
cm = confusion_matrix(y_teste_classes, y_pred_classes)
plotar_matriz_confusao(cm, classes=['Classe 0', 'Classe 1'], title=f'Matriz de Confusão para {nome_arquivo}')

# Gerar relatório de classificação
print(f"Relatório de Classificação para {nome_arquivo}:\n {classification_report(y_teste_classes, y_pred_classes)}\n")
# Out:
# VALE3 -> Acurácia: 51.37%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Relatório de Classificação para VALE3:
#                precision    recall  f1-score   support
#
#            0       0.51      1.00      0.67       601
#            1       0.87      0.03      0.06       602
#
#     accuracy                           0.51      1203
#    macro avg       0.69      0.51      0.37      1203
# weighted avg       0.69      0.51      0.37      1203

# %% [markdown]
# ## Treinamento de Redes Neurais Convolucionais (CNN)
